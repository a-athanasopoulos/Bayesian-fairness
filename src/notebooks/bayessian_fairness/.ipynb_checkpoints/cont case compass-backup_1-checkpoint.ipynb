# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
exp_name = "exp_compass"
exp_number = "exp_debug"
base_path = "/Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/"
data_path = base_path + "/my_code/Bayesian-fairness/data"
save_path = base_path + f"/my_code/Bayesian-fairness/results/continuous/{exp_name}/{exp_number}"

# %% [markdown]
# # load data

# %%
def encode_data(data,unique_values):
    encoded_value = np.array([])
    for i, d in data.iterrows():
        # encode feature to an index represents the unique value.
        index = np.argmax((d.values == unique_values).all(axis=1))
        encoded_value = np.append(encoded_value, index)
    return encoded_value.astype(int)

# %%
# set atributes
Z_atr = ["sex", "race"]
X_atr = ['age_cat', 'juv_fel_count', 'juv_misd_count', 'juv_other_count', 'priors_count', 'c_charge_degree']
Y_atr = 'two_year_recid'

# clip_features = ["juv_fel_count", "juv_misd_count", "juv_other_count", "priors_count"]

# %%
dataset = pd.read_csv(data_path + "/compas.csv")

# %%
# get distinct values
unique_z = np.unique(dataset[Z_atr].values, axis=0)
n_z = len(unique_z)

unique_y = np.unique(dataset[Y_atr].values, axis=0)
n_y = len(unique_y)

unique_x = np.unique(dataset[X_atr].values, axis=0)
n_x = len(unique_x)

# %%
print("Unique Z values:", n_z)
print("Unique X values:", n_x)
print("Unique Y values:", n_y)
# Out:
# Unique Z values: 12
# Unique X values: 604
# Unique Y values: 2

# %%
# encode z for convenience
dataset["z"] = encode_data(dataset[Z_atr], unique_values=unique_z)

# %%
Z_atr = "z"

# %%
train_data = dataset.iloc[0:6000]
test_data = dataset.iloc[6000:]

# %%
print("training size:", train_data.shape)
print("testing size:", test_data.shape)
# Out:
# training size: (6000, 10)
# testing size: (1214, 10)

# %% [markdown]
# # model

# %%
def calc_freq(data, n):
    """ calculate frequency of 1D array"""
    P = np.zeros(n)
    for value in range(n):
        mask =  data == value
        P[value] = mask.mean()
    return P

def get_models(data):
    # Py
    Py = calc_freq(data[Y_atr], n_y)
    
    # Pz_y
    Pz_y = np.zeros((n_z, n_y))
    for y in range(n_y):
        mask = data[Y_atr] == y
        Pz_y[:, y] = calc_freq(data.loc[mask, Z_atr], n_z)
    
    # Py_x
    from sklearn.linear_model import LogisticRegression
    model_y_x = LogisticRegression()
    model_y_x.fit(X = data[X_atr], y = data[Y_atr])
    
    # Pz_yx
    input_features = X_atr+[Y_atr]
    model_z_yx = LogisticRegression(max_iter=1000)
    model_z_yx.fit(X = data[input_features], y = data[Z_atr])
    
    return Py, Pz_y, model_y_x, model_z_yx

# %% [markdown]
# # calc Py

# %%
# calc Py
Py = calc_freq(test_data[Y_atr], n_y)
Py
# Out:
# array([0.54118616, 0.45881384])

# %% [markdown]
# # calc Pz_y

# %%
Pz_y = np.zeros((n_z, n_y))
for y in range(n_y):
    mask = test_data[Y_atr] == y
    Pz_y[:, y] = calc_freq(test_data.loc[mask, Z_atr], n_z)

# %%
Pz_y
# Out:
# array([[0.0456621 , 0.03052065],
#        [0.34855403, 0.50448833],
#        [0.29680365, 0.2064632 ],
#        [0.08066971, 0.06642729],
#        [0.00152207, 0.00359066],
#        [0.        , 0.00179533],
#        [0.01674277, 0.005386  ],
#        [0.09589041, 0.1059246 ],
#        [0.0913242 , 0.05924596],
#        [0.02283105, 0.01436266],
#        [0.        , 0.        ],
#        [0.        , 0.00179533]])

# %% [markdown]
# # calc P(y | x)

# %%
# !pip install -U scikit-learn

# %%
# logistic regression to model P(y|x)

from sklearn.linear_model import LogisticRegression
model_y_x = LogisticRegression()
model_y_x.fit(X = test_data[X_atr], y = test_data[Y_atr])

# todo do cross validation for the hyperparameter
# todo check better model?
# Out:
# LogisticRegression()

# %%
# some tests

# from sklearn.linear_model import LogisticRegression
# model_y_x = LogisticRegression().fit(X = train_data[X_atr], y = train_data[Y_atr])
# acc = model_y_x.score(test_data[X_atr],test_data[Y_atr])
# acc # not good acc on testset

# from sklearn.ensemble import RandomForestClassifier
# model_y_x = RandomForestClassifier()
# model_y_x.fit(X = train_data[X_atr], y = train_data[Y_atr])
# acc = model_y_x.score(test_data[X_atr],test_data[Y_atr])
# acc # not good acc on testset

# %% [markdown]
# # calc P(z | y, x)

# %%
# logistic regression to model P(z|x,y)

from sklearn.linear_model import LogisticRegression

input_features = X_atr+[Y_atr]
model_z_yx = LogisticRegression(max_iter=1000)
model_z_yx.fit(X = test_data[input_features], y = test_data[Z_atr])

# todo do cross validation for the hyperparameter
# todo check better model?
# Out:
# LogisticRegression(max_iter=1000)

# %%
model_z_yx.score(train_data[X_atr+[Y_atr]],train_data[Z_atr])
# Out:
# 0.44966666666666666

# %%
# #some tests

# from sklearn.linear_model import LogisticRegression
# model_y_x = LogisticRegression().fit(X = train_data[input_features], y = train_data[Z_atr])
# acc = model_y_x.score(test_data[input_features],test_data[Z_atr])
# print("accuracy logistic regresion :", acc) # not good acc on testset

# from sklearn.ensemble import RandomForestClassifier
# model_y_x = RandomForestClassifier()
# model_y_x.fit(X = train_data[input_features], y = train_data[Z_atr])
# acc = model_y_x.score(test_data[input_features], test_data[Z_atr])
# print("accuracy RandomForest Classifier :", acc) # not good acc on testset

# %% [markdown]
# # Train policy

# %%
num_X = n_x # number of features
num_Y = n_y # number of outcomes
num_Z = n_z # number of sensitive features
num_A = 2 # number of actions

# %%
# parameters
n_iter = 400 # number of itteration for SGD
lr = 1.0 # learning rate
l = 0.5 # lambda

# %% [markdown]
# # Functions

# %%
def get_eye_utility(size):
    return np.eye(size)

utility = get_eye_utility(size=2)

# %% [markdown]
# # Algorithm
# ![Screenshot%202023-01-20%20at%203.01.34%20PM.png](attachment:Screenshot%202023-01-20%20at%203.01.34%20PM.png)

# %%
Py
# Out:
# array([0.54118616, 0.45881384])

# %%
Pz_y
# Out:
# array([[0.0456621 , 0.03052065],
#        [0.34855403, 0.50448833],
#        [0.29680365, 0.2064632 ],
#        [0.08066971, 0.06642729],
#        [0.00152207, 0.00359066],
#        [0.        , 0.00179533],
#        [0.01674277, 0.005386  ],
#        [0.09589041, 0.1059246 ],
#        [0.0913242 , 0.05924596],
#        [0.02283105, 0.01436266],
#        [0.        , 0.        ],
#        [0.        , 0.00179533]])

# %%
def custom_mean_squared_error(y_true, y_pred):
    return tf.math.reduce_mean(tf.square(y_true - y_pred))

# %%
def get_fairness_loss(Pa_x, Py, Pz_y, model_y_x, model_z_yx):
    f =  tf.math.log(Pa_x) * (model_z_yx - Pz_y) * (model_y_x / Py)
    return tf.math.reduce_mean(f)

# %%
import tensorflow as tf

class LogisticRegresionTF(tf.keras.Model):
    """
    logistic regresion model , tensorflow
    """
    def __init__(self, input_dim, l):
        super(LogisticRegresionTF, self).__init__()
        self.l = l
        
        w_init = tf.random_normal_initializer()
        self.w = tf.Variable(
            initial_value=w_init(shape=(input_dim, 1), dtype="float32"),
            trainable=True,
        )
        
        b_init = tf.zeros_initializer()
        self.b = tf.Variable(
            initial_value=b_init(shape=(), dtype="float32"),
            trainable=True
        )

    def call(self, inputs):
        return tf.nn.sigmoid(tf.matmul(inputs,self.w) + self.b)
    
    def train_step(self, data):
        x, y, sample_weight = data_adapter.unpack_x_y_sample_weight(data)
        # Run forward pass.
        with tf.GradientTape() as tape:
            y_pred = self(x, training=True)
            utility = self.compute_loss(x, y, y_pred, sample_weight)
            fairness_loss = get_fairness_loss(y_pred, Py, Pz_y, model_y_x, model_z_yx)
            loss = (1-self.l) * utility + self.l * fairness_loss
            
        self._validate_target_and_loss(y, loss)
        # Run backwards pass.
        self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
        return self.compute_metrics(x, y, y_pred, sample_weight)

# %%
policy = LogisticRegresionTF(input_dim=len(X_atr))

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.001)
policy.compile(optimizer=optimizer,
               loss = "BinaryCrossentropy",
               metrics = ["accuracy"])

# %%
history = policy.fit(train_data[X_atr].astype("float32"),
                     train_data[Y_atr],
                     epochs=200,
                     batch_size=64,
                     validation_split=0.2,
                     shuffle=True).history
# Out:
# Epoch 1/200
# 75/75 [==============================] - 0s 1ms/step - loss: 0.6864 - accuracy: 0.5383 - val_loss: 0.6771 - val_accuracy: 0.5625
# Epoch 2/200
# 75/75 [==============================] - 0s 512us/step - loss: 0.6797 - accuracy: 0.5481 - val_loss: 0.6707 - val_accuracy: 0.6058
# Epoch 3/200
# 75/75 [==============================] - 0s 497us/step - loss: 0.6760 - accuracy: 0.5998 - val_loss: 0.6663 - val_accuracy: 0.6233
# Epoch 4/200
# 75/75 [==============================] - 0s 509us/step - loss: 0.6732 - accuracy: 0.6019 - val_loss: 0.6630 - val_accuracy: 0.6233
# Epoch 5/200
# 75/75 [==============================] - 0s 488us/step - loss: 0.6707 - accuracy: 0.6177 - val_loss: 0.6603 - val_accuracy: 0.6500
# Epoch 6/200
# 75/75 [==============================] - 0s 479us/step - loss: 0.6684 - accuracy: 0.6371 - val_loss: 0.6580 - val_accuracy: 0.6508
# Epoch 7/200
# 75/75 [==============================] - 0s 484us/step - loss: 0.6663 - accuracy: 0.6408 - val_loss: 0.6557 - val_accuracy: 0.6625
# Epoch 8/200
# 75/75 [==============================] - 0s 491us/step - loss: 0.6643 - accuracy: 0.6508 - val_loss: 0.6537 - val_accuracy: 0.6608
# 75/75 [==============================] - 0s 482us/step - loss: 0.6230 - accuracy: 0.6631 - val_loss: 0.6072 - val_accuracy: 0.6700
# Epoch 187/200
# 75/75 [==============================] - 0s 474us/step - loss: 0.6231 - accuracy: 0.6615 - val_loss: 0.6073 - val_accuracy: 0.6700
# Epoch 188/200
# 75/75 [==============================] - 0s 478us/step - loss: 0.6230 - accuracy: 0.6629 - val_loss: 0.6072 - val_accuracy: 0.6700
# Epoch 189/200
# 75/75 [==============================] - 0s 490us/step - loss: 0.6230 - accuracy: 0.6629 - val_loss: 0.6071 - val_accuracy: 0.6700
# Epoch 190/200
# 75/75 [==============================] - 0s 473us/step - loss: 0.6230 - accuracy: 0.6625 - val_loss: 0.6072 - val_accuracy: 0.6700
# Epoch 191/200
# 75/75 [==============================] - 0s 482us/step - loss: 0.6230 - accuracy: 0.6629 - val_loss: 0.6071 - val_accuracy: 0.6700
# Epoch 192/200
# 75/75 [==============================] - 0s 484us/step - loss: 0.6230 - accuracy: 0.6631 - val_loss: 0.6072 - val_accuracy: 0.6700
# Epoch 193/200
# 75/75 [==============================] - 0s 469us/step - loss: 0.6230 - accuracy: 0.6629 - val_loss: 0.6071 - val_accuracy: 0.6700
# Epoch 194/200
# 75/75 [==============================] - 0s 461us/step - loss: 0.6229 - accuracy: 0.6629 - val_loss: 0.6070 - val_accuracy: 0.6700
# Epoch 195/200
# 75/75 [==============================] - 0s 475us/step - loss: 0.6229 - accuracy: 0.6633 - val_loss: 0.6070 - val_accuracy: 0.6700
# Epoch 196/200
# 75/75 [==============================] - 0s 474us/step - loss: 0.6229 - accuracy: 0.6623 - val_loss: 0.6070 - val_accuracy: 0.6700
# Epoch 197/200
# 75/75 [==============================] - 0s 481us/step - loss: 0.6229 - accuracy: 0.6623 - val_loss: 0.6070 - val_accuracy: 0.6700
# Epoch 198/200
# 75/75 [==============================] - 0s 480us/step - loss: 0.6229 - accuracy: 0.6627 - val_loss: 0.6071 - val_accuracy: 0.6700
# Epoch 199/200
# 75/75 [==============================] - 0s 469us/step - loss: 0.6229 - accuracy: 0.6619 - val_loss: 0.6070 - val_accuracy: 0.6700
# Epoch 200/200
# 75/75 [==============================] - 0s 477us/step - loss: 0.6229 - accuracy: 0.6625 - val_loss: 0.6070 - val_accuracy: 0.6700

# %%
history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.figure()
plt.plot(history["loss"],label="loss")
plt.plot(history["val_loss"],label="val_loss")
plt.legend()
plt.show()

plt.figure()
plt.plot(history["accuracy"],label="accuracy")
plt.plot(history["val_accuracy"],label="val_accuracy")
plt.legend()
plt.show()

# %%
policy.history
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[155], line 1
# ----> 1 policy.history()
#
# TypeError: 'History' object is not callable

# %%
policy.evaluate(test_data[X_atr].astype("float32"),
                test_data[Y_atr])
# Out:
# 38/38 [==============================] - 0s 324us/step - loss: 0.6209 - accuracy: 0.6532
# [0.620853066444397, 0.6532125473022461]

# %%
tf.matmul(train_data[X_atr].astype("float32"), policy.w)
# Out:
# <tf.Tensor: shape=(6000, 1), dtype=float32, numpy=
# array([[-0.07511929],
#        [-0.05233355],
#        [ 0.599429  ],
#        ...,
#        [ 0.22115201],
#        [ 0.7178925 ],
#        [ 0.07301636]], dtype=float32)>

# %%
policy.predict(train_data[X_atr].astype("float32"))
# Out:
# 188/188 [==============================] - 0s 257us/step
# array([[0.48122904],
#        [0.4869196 ],
#        [0.64552563],
#        ...,
#        [0.5550638 ],
#        [0.6721428 ],
#        [0.518246  ]], dtype=float32)

# %% [markdown]
# #### fairness functions

# %%
def get_fairness(policy, model_delta):
    (X, Y, Z) = model_delta.shape
    fairness = 0
    for y in range(Y):
        for z in range(Z):
            delta = np.matmul(policy, model_delta[:, y , z ])
            fairness += np.linalg.norm(delta, 1)
    return fairness

# %% [markdown]
# #### utility functions

# %%
def get_utility(policy, model, utility):
    """
    Calculate expected utility
    Todo: vectorize operation - minor
    """
    A, X = policy.shape
    Y = A
    Eu = 0
    for x in range(X):
        for y in range(Y):
            for a in range(A):
                Eu += utility[a,y] * policy[a,x] * model.Pxy[x,y]
                
    return Eu

# %% [markdown]
# #### opt functions

# %%
def evaluate(true_model, true_model_delta, policy, utility, l):
    """
    Evaluate policy on true model
    """
    results = {}
    results["fairness"] = np.round(get_fairness(policy, true_model_delta),4)
    results["utility"] = get_utility(policy, true_model, utility)
    results["total"] = (1 - l) * results["utility"] - l * results["fairness"]
    return results

# %%
def update_policy(policy, model, utility, l, lr, n_iter):
    """
    Marginal Policy Dirichlet
    """
    model.get_marginal_model()
    model_delta = get_delta(model.Px_y, model.Px_yz)
    
    for i in range(n_iter):
        fairness_gradient = get_fairness_gradient(policy, model_delta)
        utility_gradient = get_utility_gradient(policy, model, utility)
        gradient = (1 - l) * utility_gradient #+ l * fairness_gradient # minus on the gradient calc.
        gradient = project_gradient(gradient)
        policy = policy + lr * gradient # maximize Utility & minimize fairness constrain.
        policy = normilize_policy(policy)
    
    return policy

# %%
def update_policy_bayesian(policy, model, utility, l, lr, n_iter, n_model):
    """
    Marginal Policy Dirichlet
    """
    models = []
    model_delta = []
    for m in range(n_model):
        models += [model.sample_model()]
        model_delta += [get_delta(model.Px_y, model.Px_yz)]
    
    for i in range(n_iter):
        tmp_index = i%n_model
        tmp_model = models[tmp_index]
        tmp_delta = model_delta[tmp_index]
        fairness_gradient = get_fairness_gradient(policy, tmp_delta)
        utility_gradient = get_utility_gradient(policy, tmp_model, utility)
        gradient = (1 - l) * utility_gradient + l * fairness_gradient # minus on the gradient calc.
        gradient = project_gradient(gradient)
        policy = policy + lr * gradient # maximize Utility & minimize fairness constrain.
        policy = normilize_policy(policy)
    
    return policy

# %%
# reproduce results
stop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 2
#       1 # reproduce results
# ----> 2 stop
#
# NameError: name 'stop' is not defined

# %%
def load_org_policy(org_path_results):
    file = pd.read_csv(org_path_results + "/policy.csv")
    p_1 = file.iloc[4].values
    p_2 = file.iloc[5].values
    p_1 = [float(x) for x in p_1[0].split(" ")[1:]]
    p_2 = [float(x) for x in p_2[0].split(" ")[1:]]
    return np.array([p_1, p_2])
# [float(x) for x in p_1[0].split(" ")[1:]]

# %%
org_path_results = "/Users/andreasathanasopoulos/Phd/projects/bayesian_fairness/org_code/bayesian-fairness/src/octave"
policy = load_org_policy(org_path_results)
policy.shape
# Out:
# (2, 141)

# %%
l
# Out:
# 0.5

# %%
steps = horizon // update_policy_period

results = []
for step in range(steps):    
    # update policy step
    policy = update_policy_bayesian(policy, belief, utility, l, lr, n_iter, n_model= n_samples) # SDG to update policy
    
    # evaluation step
    step_results = evaluate(true_dirichlet_model, true_model_delta, policy, utility, l)
    results += [step_results]
    
    # update belief step
    data_start_index = step * update_policy_period
    data_stop_index = min(data_start_index + update_policy_period, horizon)
    belief.update_posterior_belief(train_data.iloc[data_start_index : data_stop_index])
    
    print(f"--- Step : {data_start_index + 1} \n  ------- {step_results}")
# Out:
# --- Step : 1
#   ------- {'fairness': 1.0724, 'utility': 0.5085232806340967, 'total': -0.28193835968295167}
# --- Step : 101
#   ------- {'fairness': 1.2059, 'utility': 0.5322166468861395, 'total': -0.33684167655693026}
# --- Step : 201
#   ------- {'fairness': 1.2284, 'utility': 0.5427516654631265, 'total': -0.34282416726843673}
# --- Step : 301
#   ------- {'fairness': 1.2447, 'utility': 0.5607376651827342, 'total': -0.3419811674086329}
# --- Step : 401
#   ------- {'fairness': 1.3375, 'utility': 0.5676249997190701, 'total': -0.3849375001404649}
# --- Step : 501
#   ------- {'fairness': 1.3915, 'utility': 0.5752362099178097, 'total': -0.40813189504109515}
# --- Step : 601
#   ------- {'fairness': 1.1161, 'utility': 0.5766224706997715, 'total': -0.2697387646501143}
# --- Step : 701
#   ------- {'fairness': 1.0681, 'utility': 0.5771768451508462, 'total': -0.24546157742457692}
# --- Step : 801
#   ------- {'fairness': 1.0126, 'utility': 0.5732163035773954, 'total': -0.21969184821130228}
# --- Step : 901
#   ------- {'fairness': 1.0336, 'utility': 0.5741074496809928, 'total': -0.22974627515950363}
# --- Step : 1001
#   ------- {'fairness': 0.8807, 'utility': 0.5704201607684527, 'total': -0.15513991961577367}
# --- Step : 1101
#   ------- {'fairness': 1.0544, 'utility': 0.5738058763305844, 'total': -0.24029706183470778}
# --- Step : 1201
#   ------- {'fairness': 1.0067, 'utility': 0.5730790447194284, 'total': -0.21681047764028577}
# --- Step : 1301
#   ------- {'fairness': 0.8861, 'utility': 0.5696725474252531, 'total': -0.15821372628737346}
# --- Step : 1401
#   ------- {'fairness': 0.8721, 'utility': 0.5691978401508888, 'total': -0.1514510799245556}
# --- Step : 1501
#   ------- {'fairness': 0.8148, 'utility': 0.5691082895584345, 'total': -0.12284585522078273}
# --- Step : 1601
#   ------- {'fairness': 0.8455, 'utility': 0.5674501877673198, 'total': -0.1390249061163401}
# --- Step : 1701
#   ------- {'fairness': 0.9491, 'utility': 0.5710640513032448, 'total': -0.18901797434837764}
# --- Step : 1801
#   ------- {'fairness': 0.8335, 'utility': 0.5692977501943267, 'total': -0.13210112490283665}
# --- Step : 1901
#   ------- {'fairness': 0.8644, 'utility': 0.5706184561826093, 'total': -0.14689077190869532}
# --- Step : 2001
#   ------- {'fairness': 0.961, 'utility': 0.5714688583066335, 'total': -0.19476557084668322}
# --- Step : 2101
#   ------- {'fairness': 0.9929, 'utility': 0.5705100936724481, 'total': -0.21119495316377596}
# --- Step : 2201
#   ------- {'fairness': 0.991, 'utility': 0.5701395552032751, 'total': -0.21043022239836245}
# --- Step : 2301
#   ------- {'fairness': 0.9404, 'utility': 0.5672536915556518, 'total': -0.18657315422217413}
# --- Step : 2401
#   ------- {'fairness': 0.9645, 'utility': 0.5695395977349564, 'total': -0.1974802011325218}
# --- Step : 2501
#   ------- {'fairness': 0.9875, 'utility': 0.570466203242256, 'total': -0.208516898378872}
# --- Step : 2601
#   ------- {'fairness': 0.9871, 'utility': 0.5726803954519073, 'total': -0.20720980227404634}
# --- Step : 2701
#   ------- {'fairness': 1.1035, 'utility': 0.5756426471574357, 'total': -0.2639286764212821}
# --- Step : 2801
#   ------- {'fairness': 1.1069, 'utility': 0.5768264221495184, 'total': -0.2650367889252408}
# --- Step : 2901
#   ------- {'fairness': 1.1739, 'utility': 0.5750372983728615, 'total': -0.2994313508135692}
# --- Step : 3001
#   ------- {'fairness': 1.2854, 'utility': 0.5796236889879257, 'total': -0.3528881555060372}
# --- Step : 3101
#   ------- {'fairness': 1.1404, 'utility': 0.5778048602119936, 'total': -0.28129756989400323}
# --- Step : 3201
#   ------- {'fairness': 1.1936, 'utility': 0.5780779480177668, 'total': -0.3077610259911166}
# --- Step : 3301
#   ------- {'fairness': 1.176, 'utility': 0.5788230621425688, 'total': -0.29858846892871554}
# --- Step : 3401
#   ------- {'fairness': 1.1773, 'utility': 0.5820087207423399, 'total': -0.29764563962883006}
# --- Step : 3501
#   ------- {'fairness': 1.1862, 'utility': 0.5782700756127384, 'total': -0.3039649621936308}
# --- Step : 3601
#   ------- {'fairness': 1.1575, 'utility': 0.5778157444076176, 'total': -0.2898421277961912}
# --- Step : 3701
#   ------- {'fairness': 1.2316, 'utility': 0.5756997852764102, 'total': -0.3279501073617949}
# --- Step : 3801
#   ------- {'fairness': 1.1137, 'utility': 0.5720830475578897, 'total': -0.2708084762210551}
# --- Step : 3901
#   ------- {'fairness': 1.1519, 'utility': 0.5734961891604733, 'total': -0.2892019054197633}
# --- Step : 4001
#   ------- {'fairness': 1.1726, 'utility': 0.5760573425782496, 'total': -0.29827132871087525}
# --- Step : 4101
#   ------- {'fairness': 1.1815, 'utility': 0.5771499977012503, 'total': -0.30217500114937484}
# --- Step : 4201
#   ------- {'fairness': 1.1823, 'utility': 0.5762253513595144, 'total': -0.3030373243202428}
# --- Step : 4301
#   ------- {'fairness': 1.1621, 'utility': 0.5741140344264497, 'total': -0.2939929827867751}
# --- Step : 4401
#   ------- {'fairness': 1.2372, 'utility': 0.5760446253435819, 'total': -0.3305776873282091}
# --- Step : 4501
#   ------- {'fairness': 1.3268, 'utility': 0.5776718114329958, 'total': -0.37456409428350207}
# --- Step : 4601
#   ------- {'fairness': 1.2685, 'utility': 0.5754365698872528, 'total': -0.3465317150563736}
# --- Step : 4701
#   ------- {'fairness': 1.2296, 'utility': 0.577384148192581, 'total': -0.3261079259037095}
# --- Step : 4801
#   ------- {'fairness': 1.2686, 'utility': 0.5767402223926323, 'total': -0.3459298888036838}
# --- Step : 4901
#   ------- {'fairness': 1.2665, 'utility': 0.5790818292929728, 'total': -0.3437090853535136}
# --- Step : 5001
#   ------- {'fairness': 1.3077, 'utility': 0.5780563645448414, 'total': -0.3648218177275793}
# --- Step : 5101
#   ------- {'fairness': 1.2673, 'utility': 0.5798697284470415, 'total': -0.3437151357764793}
# --- Step : 5201
#   ------- {'fairness': 1.3044, 'utility': 0.5775188521469917, 'total': -0.36344057392650414}
# --- Step : 5301
#   ------- {'fairness': 1.2719, 'utility': 0.5757082125629668, 'total': -0.3480958937185166}
# --- Step : 5401
#   ------- {'fairness': 1.3465, 'utility': 0.5774570439419999, 'total': -0.38452147802900005}
# --- Step : 5501
#   ------- {'fairness': 1.252, 'utility': 0.5775641548254525, 'total': -0.33721792258727373}
# --- Step : 5601
#   ------- {'fairness': 1.4187, 'utility': 0.5830256520987124, 'total': -0.41783717395064385}
# --- Step : 5701
#   ------- {'fairness': 1.4359, 'utility': 0.5825654973251793, 'total': -0.42666725133741035}
# --- Step : 5801
#   ------- {'fairness': 1.5403, 'utility': 0.5857276751781516, 'total': -0.4772861624109242}
# --- Step : 5901
#   ------- {'fairness': 1.38, 'utility': 0.5815113813821298, 'total': -0.39924430930893506}

# %%
pd_resutls = pd.DataFrame(results)

# %% [markdown]
# # plots

# %%
pd_resutls[["utility"]].plot()
# Out:
# <AxesSubplot: >

# %%
org = pd.read_csv(org_path_results + "/results.csv")

# %%
def fix_results(r):
    new_r = [float(sr.split(" ")[1]) for sr in r]
    return new_r

r1 = fix_results(org.iloc[9: 64 + 9 - 3]["# Created by Octave 6.2.0"].values)
r2 = fix_results(org.iloc[74: 64 + 74 - 3]["# Created by Octave 6.2.0"].values)
r3 = fix_results(org.iloc[139: 64 + 139 - 3]["# Created by Octave 6.2.0"].values)
# r4 = fix_results(org.iloc[204: 64 + 204]["# Created by Octave 6.2.0"].values)

org_pd = pd.DataFrame([r1,r2,r3]).T
org_pd.columns = ["utility","total","fairness"]

# %%
org_pd
# Out:
#      utility     total  fairness
# 0   0.506852 -0.190459  0.887770
# 1   0.518125 -0.251298  1.020722
# 2   0.539687 -0.395636  1.330959
# 3   0.551335 -0.328179  1.207693
# 4   0.560333 -0.326149  1.212631
# ..       ...       ...       ...
# 56  0.581704 -0.407236  1.396176
# 57  0.588373 -0.514486  1.617344
# 58  0.584481 -0.470888  1.526257
# 59  0.585359 -0.450287  1.485933
# 60  0.583901 -0.426942  1.437784
#
# [61 rows x 3 columns]

# %%
org_pd["utility"].plot()
pd_resutls["utility"].plot()
# Out:
# <AxesSubplot: >

# %%
org_pd["fairness"].plot()
pd_resutls["fairness"].plot()
# Out:
# <AxesSubplot: >

# %%
org_pd["total"].plot()
pd_resutls["total"].plot()
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Questions

# %%
1. ProjectPolicyGradient ???
